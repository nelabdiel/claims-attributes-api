# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix

from sklearn.externals import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from scipy.spatial import distance as dist

import time
from IPython.display import clear_output

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('.CleanDataCC.csv', index_col=0)
df.head()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Applications/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                  CLMANT_TXT CNTNTN_CLSFCN_ID         CNTNTN_CLSFCN_TXT  \
# 0  diabetes mellitus type 2             2085  diabetes mellitus type 2
# 1  diabetes mellitus type 2             2085  diabetes mellitus type 2
# 2   special monthly pension             8917             miscellaneous
# 3   special monthly pension             8917             miscellaneous
# 4       adjustment disorder             2030                depression
#
#                                modeClass  \
# 0                              endocrine
# 1                              endocrine
# 2  pension aid and attendance housebound
# 3  pension aid and attendance housebound
# 4                       mental disorders
#
#                                   newClass
# 0                                endocrine
# 1                                endocrine
# 2  pension - aid and attendence/housebound
# 3  pension - aid and attendence/housebound
# 4                         mental disorders

# %%
df.shape
# Out:
# (6324799, 5)

# %%
df = df[df['CLMANT_TXT'].str.len() < 300]
df.shape
# Out:
# (6324248, 5)

# %% [markdown]
# # Lets remove from df things that dont have a label that coincides with the official classes but keep them in a different dataframe for later.

# %%
dfOut = df[(~df['CLMANT_TXT'].isnull()) & (df['newClass'].isnull())]
df = df[(~df['CLMANT_TXT'].isnull()) & (~df['newClass'].isnull())]

# %% [markdown]
# # Initialize a Count Vectorizer with a minimum of 10 appearance of a word for significance, english stopwords and up to 3 word ngrams.

# %%
vectorizer = CountVectorizer(min_df=10, ngram_range=(1,3), stop_words='english') 
#vectorizer = TfidfVectorizer(min_df=10, ngram_range=(1,3), stop_words='english')

# %%
X = vectorizer.fit_transform(df['CLMANT_TXT'])

# %%
y = df['newClass']

# %% [markdown]
# # Split first to obtain Training set

# %%
X_train, X_test, y_train, y_test, i_train, i_test = train_test_split(X, y, df.index, test_size=0.6, random_state=42)

# %% [markdown]
# # Split again test to obtain testing and validation

# %%
X_test, X_validate, y_test, y_validate, i_test, i_validate = train_test_split(X_test, y_test, i_test, 
                                                                              test_size=0.5, random_state=42)

# %% [markdown]
# # Initialize a Logistic Regression Classifier

# %%
clf = LogisticRegression(n_jobs=-1)
#clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0)

# %%
clf.fit(X_train, y_train)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:1297: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 8.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=-1,
#           penalty='l2', random_state=None, solver='warn', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# # Predict the value of our testing set

# %%
y_validate_pred = clf.predict(X_validate)
y_validate_pred
# Out:
# array(['musculoskeletal - foot',
#        'neurological - cranial/peripheral nerves',
#        'musculoskeletal - shoulder', ..., 'musculoskeletal - hip',
#        'digestive',
#        'infectious diseases, immune disorders & nutritional deficiencies'],
#       dtype=object)

# %%
y_validate_pred[:100]
# Out:
# array(['musculoskeletal - foot',
#        'neurological - cranial/peripheral nerves',
#        'musculoskeletal - shoulder', 'musculoskeletal - knee', 'skin',
#        'special monthly compensation - aid and attendence/housebound',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'hearing loss', 'musculoskeletal - other',
#        'musculoskeletal - arthritis', 'hearing loss', 'eye (vision)',
#        'hearing loss', 'hearing loss', 'musculoskeletal - shoulder',
#        'musculoskeletal - neck/upper back (cervical spine)',
#        'hearing loss', 'hearing loss', 'musculoskeletal - ankle',
#        'mental disorders', 'cyst/benign growth - musculoskeletal - other',
#        'gulf war undiagnosed illness', 'skin', 'heart/veins/arteries',
#        'musculoskeletal and muscle injuries', 'musculoskeletal - foot',
#        'cancer - skin',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'mental disorders', 'hearing loss',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'genitourinary',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'musculoskeletal - wrist', 'service connected death',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'musculoskeletal - hand',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'musculoskeletal - foot',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'respiratory', 'cancer - genitourinary', 'digestive',
#        'cancer - genitourinary', 'musculoskeletal - hand', 'hearing loss',
#        'hearing loss',
#        'musculoskeletal - neck/upper back (cervical spine)',
#        'neurological - cranial/peripheral nerves', 'hearing loss',
#        'administrative issue',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'pension', 'hearing loss', 'mental disorders',
#        'heart/veins/arteries', 'hearing loss', 'musculoskeletal - ankle',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'infectious diseases, immune disorders & nutritional deficiencies',
#        'mental disorders', 'unemployability', 'musculoskeletal - hip',
#        'administrative issue', 'musculoskeletal - wrist', 'hearing loss',
#        'respiratory', 'administrative issue', 'musculoskeletal - ankle',
#        'hearing loss', 'hearing loss', 'traumatic brain injury',
#        'gynecological', 'hearing loss', 'musculoskeletal - ankle',
#        'endocrine',
#        'post traumatic stress disorder (ptsd) combat - mental disorders',
#        'respiratory', 'musculoskeletal - foot', 'pension',
#        'neurological - cranial/peripheral nerves',
#        'musculoskeletal - elbow', 'mental disorders', 'mental disorders',
#        'neurological other system', 'eye (vision)',
#        'scars (extremeties and trunk)',
#        'musculoskeletal - mid/lower back (thoracolumbar spine)',
#        'unemployability', 'genitourinary', 'genitourinary',
#        'musculoskeletal - foot', 'hearing loss', 'skin',
#        'unemployability', 'musculoskeletal - foot', 'unemployability',
#        'genitourinary'], dtype=object)

# %%
list(y_validate)
# Out:
# ['musculoskeletal - foot',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - shoulder',
#  'musculoskeletal - knee',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'special monthly compensation - aid and attendence/housebound',
#  'leg condition - neurological other system',
#  'hearing loss',
#  'musculoskeletal - other',
#  'musculoskeletal - arthritis',
#  'hearing loss',
#  'eye (vision)',
#  'hearing loss',
#  'hearing loss',
#  'musculoskeletal - shoulder',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'hearing loss',
#  'hearing loss',
#  'musculoskeletal - ankle',
#  'mental disorders',
#  'cyst/benign growth - musculoskeletal - other',
#  'gulf war undiagnosed illness',
#  'skin',
#  'heart/veins/arteries',
#  'musculoskeletal - other',
#  'musculoskeletal - foot',
#  'musculoskeletal - other',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'mental disorders',
#  'hearing loss',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'genitourinary',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - wrist',
#  'service connected death',
#  'mental disorders',
#  'musculoskeletal - hand',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - foot',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'respiratory',
#  'cancer - genitourinary',
#  'digestive',
#  'cancer - genitourinary',
#  'musculoskeletal - hand',
#  'hearing loss',
#  'hearing loss',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'administrative issue',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'pension',
#  'hearing loss',
#  'mental disorders',
#  'heart/veins/arteries',
#  'hearing loss',
#  'musculoskeletal - ankle',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'mental disorders',
#  'unemployability',
#  'musculoskeletal - hip',
#  'respiratory',
#  'musculoskeletal - wrist',
#  'hearing loss',
#  'respiratory',
#  'administrative issue',
#  'musculoskeletal - arthritis',
#  'hearing loss',
#  'hearing loss',
#  'traumatic brain injury',
#  'gynecological',
#  'hearing loss',
#  'musculoskeletal - ankle',
#  'endocrine',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'respiratory',
#  'musculoskeletal - foot',
#  'pension',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - elbow',
#  'None',
#  'mental disorders',
#  'neurological other system',
#  'eye (vision)',
#  'scars (extremeties and trunk)',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'unemployability',
#  'genitourinary',
#  'genitourinary',
#  'musculoskeletal - foot',
#  'hearing loss',
#  'skin',
#  'unemployability',
#  'musculoskeletal - foot',
#  'unemployability',
#  'genitourinary',
#  'neurological - cranial/peripheral nerves',
#  'digestive',
#  'respiratory',
#  'musculoskeletal - ankle',
#  'musculoskeletal - foot',
#  'musculoskeletal - knee',
#  'musculoskeletal - ankle',
#  'musculoskeletal - knee',
#  'musculoskeletal - ankle',
#  'skin',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'eye (vision)',
#  'unemployability',
#  'musculoskeletal - knee',
#  'administrative issue',
#  'mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'respiratory',
#  'digestive',
#  'mental disorders',
#  'respiratory',
#  'mental disorders',
#  'hearing loss',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'respiratory',
#  'endocrine',
#  'pension',
#  'genitourinary',
#  'heart/veins/arteries',
#  'musculoskeletal - ankle',
#  'scars (extremeties and trunk)',
#  'neurological - cranial/peripheral nerves',
#  'eye (vision)',
#  'musculoskeletal - elbow',
#  'mental disorders',
#  'administrative issue',
#  'skin',
#  'mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'service connected death',
#  'musculoskeletal - knee',
#  'leg condition - neurological other system',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'heart/veins/arteries',
#  'pension',
#  'mental disorders',
#  'pension',
#  'None',
#  'musculoskeletal - foot',
#  'respiratory',
#  'mental disorders',
#  'hearing loss',
#  'administrative issue',
#  'arm condition - neurological other system',
#  'unemployability',
#  'dental and oral',
#  'hearing loss',
#  'musculoskeletal - ankle',
#  'musculoskeletal - knee',
#  'musculoskeletal - foot',
#  'heart/veins/arteries',
#  'leg condition - heart/veins/arteries',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'hearing loss',
#  'musculoskeletal - foot',
#  'respiratory',
#  'ear disease and other sense organs',
#  'neurological other system',
#  'musculoskeletal - hand',
#  'cancer - genitourinary',
#  'skin',
#  'musculoskeletal - elbow',
#  'hearing loss',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - ankle',
#  'digestive',
#  'traumatic brain injury',
#  'dental and oral',
#  'scars (head, face, or neck)',
#  'musculoskeletal - elbow',
#  'skin',
#  'skin',
#  'mental disorders',
#  'musculoskeletal - knee',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - foot',
#  'respiratory',
#  'respiratory',
#  'arm condition - neurological other system',
#  'skin',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'cancer - genitourinary',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - hand',
#  'musculoskeletal - ankle',
#  'musculoskeletal - foot',
#  'administrative issue',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'heart/veins/arteries',
#  'musculoskeletal - hand',
#  'mental disorders',
#  'musculoskeletal - other',
#  'musculoskeletal - hip',
#  'mental disorders',
#  'skin',
#  'musculoskeletal - other',
#  'administrative issue',
#  'mental disorders',
#  'unemployability',
#  'hearing loss',
#  'hearing loss',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - knee',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'respiratory',
#  'skin',
#  'neurological - cranial/peripheral nerves',
#  'neurological - cranial/peripheral nerves',
#  'administrative issue',
#  'pension',
#  'musculoskeletal - ankle',
#  'hearing loss',
#  'pension',
#  'mental disorders',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'respiratory',
#  'administrative issue',
#  'mental disorders',
#  'administrative issue',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'cancer - genitourinary',
#  'gynecological',
#  'mental disorders',
#  'musculoskeletal - foot',
#  'respiratory',
#  'musculoskeletal - ankle',
#  'musculoskeletal - hip',
#  'eye (vision)',
#  'digestive',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - other',
#  'administrative issue',
#  'hearing loss',
#  'respiratory',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'musculoskeletal - foot',
#  'musculoskeletal - other',
#  'musculoskeletal - shoulder',
#  'musculoskeletal - foot',
#  'respiratory',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'hearing loss',
#  'pension - aid and attendence/housebound',
#  'neurological - cranial/peripheral nerves',
#  'skin',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'mental disorders',
#  'traumatic brain injury',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'musculoskeletal - hip',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'scars (extremeties and trunk)',
#  'skin',
#  'special monthly compensation - aid and attendence/housebound',
#  'genitourinary',
#  'hearing loss',
#  'digestive',
#  'endocrine',
#  'musculoskeletal - foot',
#  'respiratory',
#  'scars (head, face, or neck)',
#  'hearing loss',
#  'digestive',
#  'cancer - dental and oral',
#  'pension - aid and attendence/housebound',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'hearing loss',
#  'hearing loss',
#  'neurological - cranial/peripheral nerves',
#  'scars (extremeties and trunk)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'None',
#  'ear disease and other sense organs',
#  'neurological - cranial/peripheral nerves',
#  'neurological - cranial/peripheral nerves',
#  'service connected death',
#  'traumatic brain injury',
#  'musculoskeletal - foot',
#  'mental disorders',
#  'musculoskeletal - wrist',
#  'digestive',
#  'musculoskeletal - knee',
#  'musculoskeletal - foot',
#  'respiratory',
#  'neurological - cranial/peripheral nerves',
#  'arm condition - neurological other system',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - shoulder',
#  'endocrine',
#  'cancer - genitourinary',
#  'pension',
#  'None',
#  'heart/veins/arteries',
#  'mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'musculoskeletal - ankle',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'hearing loss',
#  'respiratory',
#  'respiratory',
#  'musculoskeletal - foot',
#  'respiratory',
#  'musculoskeletal - hand',
#  'musculoskeletal - foot',
#  'special monthly compensation - aid and attendence/housebound',
#  'administrative issue',
#  'eye (vision)',
#  'musculoskeletal - hand',
#  'endocrine',
#  'eye (vision)',
#  'endocrine',
#  'hearing loss',
#  'administrative issue',
#  'administrative issue',
#  'hearing loss',
#  'musculoskeletal - wrist',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'respiratory',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'respiratory',
#  'hearing loss',
#  'heart/veins/arteries',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'gynecological',
#  'digestive',
#  'mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'respiratory',
#  'musculoskeletal - shoulder',
#  'pension',
#  'None',
#  'None',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'administrative issue',
#  'skin',
#  'hearing loss',
#  'hearing loss',
#  'pension',
#  'administrative issue',
#  'cancer - genitourinary',
#  'genitourinary',
#  'pension - aid and attendence/housebound',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'skin',
#  'heart/veins/arteries',
#  'musculoskeletal - shoulder',
#  'skin',
#  'pension',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'gynecological',
#  'pension',
#  'cancer - genitourinary',
#  'pension',
#  'special monthly compensation - anatomical loss/loss of use',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'endocrine',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'pension',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'hearing loss',
#  'genitourinary',
#  'neurological - cranial/peripheral nerves',
#  'heart/veins/arteries',
#  'respiratory',
#  'skin',
#  'skin',
#  'musculoskeletal - shoulder',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - knee',
#  'genitourinary',
#  'musculoskeletal - arthritis',
#  'musculoskeletal - foot',
#  'neurological - cranial/peripheral nerves',
#  'genitourinary',
#  'musculoskeletal - knee',
#  'musculoskeletal - ankle',
#  'endocrine',
#  'hearing loss',
#  'hearing loss',
#  'hearing loss',
#  'endocrine',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'administrative issue',
#  'mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'skin',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'eye (vision)',
#  'hearing loss',
#  'respiratory',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - foot',
#  'hearing loss',
#  'respiratory',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - hip',
#  'musculoskeletal - hand',
#  'hearing loss',
#  'genitourinary',
#  'skin',
#  'mental disorders',
#  'musculoskeletal - shoulder',
#  'respiratory',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'digestive',
#  'musculoskeletal - shoulder',
#  'hearing loss',
#  'scars (head, face, or neck)',
#  'musculoskeletal - shoulder',
#  'musculoskeletal - hand',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'cancer - skin',
#  'administrative issue',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal and muscle injuries',
#  'heart/veins/arteries',
#  'respiratory',
#  'heart/veins/arteries',
#  'heart/veins/arteries',
#  'respiratory',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - wrist',
#  'endocrine',
#  'administrative issue',
#  'genitourinary',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'neurological other system',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - shoulder',
#  'gynecological',
#  'respiratory',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - shoulder',
#  'neurological - cranial/peripheral nerves',
#  'leg condition - neurological other system',
#  'hearing loss',
#  'musculoskeletal - foot',
#  'hearing loss',
#  'endocrine',
#  'musculoskeletal - knee',
#  'musculoskeletal - hip',
#  'mental disorders',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'hearing loss',
#  'neurological - cranial/peripheral nerves',
#  'None',
#  'pension - aid and attendence/housebound',
#  'pension',
#  'respiratory',
#  'musculoskeletal - hand',
#  'mental disorders',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'hearing loss',
#  'musculoskeletal - ankle',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'respiratory',
#  'administrative issue',
#  'musculoskeletal - elbow',
#  'respiratory',
#  'cyst/benign growth - musculoskeletal - ankle',
#  'musculoskeletal - other',
#  'leg condition - neurological other system',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'digestive',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'heart/veins/arteries',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'heart/veins/arteries',
#  'respiratory',
#  'digestive',
#  'heart/veins/arteries',
#  'neurological - cranial/peripheral nerves',
#  'neurological other system',
#  'administrative issue',
#  'hearing loss',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'eye (vision)',
#  'pension',
#  'hearing loss',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - elbow',
#  'mental disorders',
#  'respiratory',
#  'musculoskeletal - knee',
#  'None',
#  'eye (vision)',
#  'hearing loss',
#  'skin',
#  'neurological other system',
#  'musculoskeletal - knee',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'digestive',
#  'musculoskeletal - hand',
#  'hearing loss',
#  'administrative issue',
#  'respiratory',
#  'hemic and lymphatic',
#  'heart/veins/arteries',
#  'mental disorders',
#  'scars (head, face, or neck)',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'musculoskeletal - hand',
#  'hearing loss',
#  'musculoskeletal - hip',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'administrative issue',
#  'administrative issue',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'hearing loss',
#  'hearing loss',
#  'mental disorders',
#  'mental disorders',
#  'musculoskeletal - hip',
#  'traumatic brain injury',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'pension - aid and attendence/housebound',
#  'digestive',
#  'heart/veins/arteries',
#  'musculoskeletal - foot',
#  'mental disorders',
#  'endocrine',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'unemployability',
#  'scars (head, face, or neck)',
#  'cancer - genitourinary',
#  'administrative issue',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'mental disorders',
#  'musculoskeletal - other',
#  'musculoskeletal - hand',
#  'musculoskeletal - knee',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - knee',
#  'administrative issue',
#  'administrative issue',
#  'musculoskeletal - ankle',
#  'hearing loss',
#  'tuberculosis',
#  'special monthly compensation - aid and attendence/housebound',
#  'hearing loss',
#  'respiratory',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'hearing loss',
#  'leg condition - neurological other system',
#  'administrative issue',
#  'respiratory',
#  'administrative issue',
#  'digestive',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'neurological other system',
#  'traumatic brain injury',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'neurological - cranial/peripheral nerves',
#  'None',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'neurological - cranial/peripheral nerves',
#  'administrative issue',
#  'service connected death',
#  'endocrine',
#  'eye (vision)',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'endocrine',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'pension - aid and attendence/housebound',
#  'neurological - cranial/peripheral nerves',
#  'mental disorders',
#  'genitourinary',
#  'genitourinary',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'heart/veins/arteries',
#  'special monthly compensation - aid and attendence/housebound',
#  'musculoskeletal - foot',
#  'eye (vision)',
#  'hearing loss',
#  'skin',
#  'hearing loss',
#  'genitourinary',
#  'hearing loss',
#  'scars (extremeties and trunk)',
#  'cold injury residuals',
#  'musculoskeletal - wrist',
#  'digestive',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'musculoskeletal - ankle',
#  'musculoskeletal - knee',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'administrative issue',
#  'pension',
#  'musculoskeletal - other',
#  'genitourinary',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'skin',
#  'administrative issue',
#  'hearing loss',
#  'administrative issue',
#  'mental disorders',
#  'musculoskeletal - other',
#  'neurological other system',
#  'heart/veins/arteries',
#  'respiratory',
#  'skin',
#  'hearing loss',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'mental disorders',
#  'respiratory',
#  'helpless child',
#  'cyst/benign growth - musculoskeletal - neck/upper back (cervical spine)',
#  'hearing loss',
#  'musculoskeletal - foot',
#  'respiratory',
#  'mental disorders',
#  'musculoskeletal - foot',
#  'musculoskeletal - other',
#  'neurological other system',
#  'administrative issue',
#  'musculoskeletal - foot',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'digestive',
#  'pension',
#  'musculoskeletal - foot',
#  'hearing loss',
#  'administrative issue',
#  'musculoskeletal - knee',
#  'musculoskeletal - knee',
#  'neurological - cranial/peripheral nerves',
#  'pension',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'mental disorders',
#  'digestive',
#  'skin',
#  'musculoskeletal - shoulder',
#  'hearing loss',
#  'digestive',
#  'pension',
#  'administrative issue',
#  'genitourinary',
#  'genitourinary',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'musculoskeletal - foot',
#  'administrative issue',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'heart/veins/arteries',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - foot',
#  'musculoskeletal - foot',
#  'None',
#  'digestive',
#  'musculoskeletal - shoulder',
#  'mental disorders',
#  'administrative issue',
#  'hearing loss',
#  'helpless child',
#  'digestive',
#  'musculoskeletal - shoulder',
#  'administrative issue',
#  'eye (vision)',
#  'endocrine',
#  'dental and oral',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'mental disorders',
#  'hearing loss',
#  'musculoskeletal - shoulder',
#  'musculoskeletal - shoulder',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'pension',
#  'cancer - respiratory',
#  'neurological other system',
#  'traumatic brain injury',
#  'musculoskeletal - hand',
#  'None',
#  'hearing loss',
#  'endocrine',
#  'musculoskeletal - hip',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'hearing loss',
#  'skin',
#  'musculoskeletal - arthritis',
#  'digestive',
#  'digestive',
#  'skin',
#  'respiratory',
#  'musculoskeletal - elbow',
#  'respiratory',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'hearing loss',
#  'musculoskeletal - shoulder',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'mental disorders',
#  'endocrine',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'respiratory',
#  'musculoskeletal - ankle',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'scars (extremeties and trunk)',
#  'administrative issue',
#  'musculoskeletal - wrist',
#  'musculoskeletal - knee',
#  'neurological - cranial/peripheral nerves',
#  'pension',
#  'mental disorders',
#  'eye (vision)',
#  'musculoskeletal - foot',
#  'endocrine',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'administrative issue',
#  'heart/veins/arteries',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'hearing loss',
#  'neurological - cranial/peripheral nerves',
#  'None',
#  'administrative issue',
#  'mental disorders',
#  'heart/veins/arteries',
#  'None',
#  'leg condition - neurological other system',
#  'leg condition - neurological other system',
#  'cancer - skin',
#  'eye (vision)',
#  'administrative issue',
#  'hearing loss',
#  'heart/veins/arteries',
#  'administrative issue',
#  'heart/veins/arteries',
#  'musculoskeletal - ankle',
#  'skin',
#  'skin',
#  'heart/veins/arteries',
#  'endocrine',
#  'hearing loss',
#  'heart/veins/arteries',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'hearing loss',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - hip',
#  'musculoskeletal - shoulder',
#  'digestive',
#  'eye (vision)',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'musculoskeletal - knee',
#  'skin',
#  'musculoskeletal - foot',
#  'respiratory',
#  'musculoskeletal - other',
#  'musculoskeletal - hand',
#  'heart/veins/arteries',
#  'genitourinary',
#  'musculoskeletal - knee',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'scars (extremeties and trunk)',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - shoulder',
#  'neurological - cranial/peripheral nerves',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'scars (extremeties and trunk)',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'respiratory',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'hearing loss',
#  'service connected death',
#  'eye (vision)',
#  'genitourinary',
#  'skin',
#  'respiratory',
#  'None',
#  'administrative issue',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'endocrine',
#  'heart/veins/arteries',
#  'None',
#  'eye (vision)',
#  'heart/veins/arteries',
#  'musculoskeletal - knee',
#  'musculoskeletal - neck/upper back (cervical spine)',
#  'unemployability',
#  'cyst/benign growth - skin',
#  'administrative issue',
#  'administrative issue',
#  'pension',
#  'genitourinary',
#  'musculoskeletal - shoulder',
#  'infectious diseases, immune disorders & nutritional deficiencies',
#  'dental and oral',
#  'service connected death',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'musculoskeletal - other',
#  'heart/veins/arteries',
#  'neurological - cranial/peripheral nerves',
#  'endocrine',
#  'musculoskeletal - shoulder',
#  'None',
#  'genitourinary',
#  'respiratory',
#  'musculoskeletal - ankle',
#  'scars (extremeties and trunk)',
#  'pension',
#  'mental disorders',
#  'mental disorders',
#  'musculoskeletal - wrist',
#  'skin',
#  'musculoskeletal - other',
#  'digestive',
#  'mental disorders',
#  'heart/veins/arteries',
#  'genitourinary',
#  'musculoskeletal - wrist',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'mental disorders',
#  'mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'neurological - cranial/peripheral nerves',
#  'dental and oral',
#  'administrative issue',
#  'mental disorders',
#  'musculoskeletal - hip',
#  'heart/veins/arteries',
#  'administrative issue',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'neurological - cranial/peripheral nerves',
#  'gynecological',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'hearing loss',
#  'mental disorders',
#  'heart/veins/arteries',
#  'mental disorders',
#  'musculoskeletal - foot',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'heart/veins/arteries',
#  'cancer - genitourinary',
#  'scars (extremeties and trunk)',
#  'administrative issue',
#  'musculoskeletal - other',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'service connected death',
#  'mental disorders',
#  'mental disorders',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'respiratory',
#  'skin',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'gynecological',
#  'skin',
#  'musculoskeletal - foot',
#  'respiratory',
#  'hearing loss',
#  'heart/veins/arteries',
#  'skin',
#  'neurological - cranial/peripheral nerves',
#  'heart/veins/arteries',
#  'administrative issue',
#  'unemployability',
#  'mental disorders',
#  'mental disorders',
#  'mental disorders',
#  'digestive',
#  'musculoskeletal - other',
#  'digestive',
#  'traumatic brain injury',
#  'neurological other system',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'musculoskeletal - arthritis',
#  'dental and oral',
#  'hearing loss',
#  'mental disorders',
#  'musculoskeletal - knee',
#  'None',
#  'mental disorders',
#  'musculoskeletal - knee',
#  'musculoskeletal - hand',
#  'musculoskeletal - foot',
#  'hearing loss',
#  'musculoskeletal - knee',
#  'respiratory',
#  'administrative issue',
#  'administrative issue',
#  'musculoskeletal - hand',
#  'leg condition - neurological other system',
#  'cancer - respiratory',
#  'skin',
#  'mental disorders',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'neurological - cranial/peripheral nerves',
#  'pension',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'musculoskeletal - other',
#  'skin',
#  'cancer - dental and oral',
#  'genitourinary',
#  'digestive',
#  'hearing loss',
#  'heart/veins/arteries',
#  'post traumatic stress disorder (ptsd) combat - mental disorders',
#  'ear disease and other sense organs',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'digestive',
#  'traumatic brain injury',
#  'musculoskeletal and muscle injuries',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'skin',
#  'post traumatic stress disorder (ptsd) personal trauma - mental disorders',
#  'heart/veins/arteries',
#  'eye (vision)',
#  'hearing loss',
#  'administrative issue',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'neurological - cranial/peripheral nerves',
#  'hearing loss',
#  'scars (extremeties and trunk)',
#  'musculoskeletal - hip',
#  'digestive',
#  'musculoskeletal - knee',
#  'musculoskeletal - arthritis',
#  'digestive',
#  'None',
#  'hearing loss',
#  'musculoskeletal - arthritis',
#  'musculoskeletal - knee',
#  'heart/veins/arteries',
#  'musculoskeletal - mid/lower back (thoracolumbar spine)',
#  'genitourinary',
#  'hearing loss',
#  ...]

# %% [markdown]
# # Lets check the models accuracy

# %%
clf.score(X_validate,y_validate)
# Out:
# 0.9097379135865913

# %% [markdown]
# # How about Presicion, Recall and f1 score

# %%
precision_recall_fscore_support(y_validate, y_validate_pred, average='weighted')
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# (0.9030600140233641, 0.9097379135865913, 0.9040597044656684, None)

# %% [markdown]
# # How about a confusion Matrix

# %%
confusion_matrix(y_validate, y_validate_pred)
# Out:
# array([[ 1895,     2,     2, ...,     0,     9,     9],
#        [    8,    67,     0, ...,     0,     1,     0],
#        [    0,     0,    21, ...,     0,     0,     0],
#        ...,
#        [    1,     0,     0, ...,    23,     0,     0],
#        [    9,     0,     0, ...,     0, 27012,     0],
#        [    2,     0,     0, ...,     0,     0,   338]])

# %%
results = pd.DataFrame()
results['validate'] = y_validate
results['validatePred'] = y_validate_pred

# %%
results['claims'] = df['CLMANT_TXT'].loc[i_test]

# %%
results['correctPred'] = results.apply(lambda x: int(x['validate'] == x['validatePred']), 1)

# %%
results.groupby('validatePred')['correctPred'].mean().sort_values(ascending=False)
# Out:
# validatePred
# cyst/benign growth - dental and oral                                       1.000000
# adhesions - respiratory                                                    1.000000
# pension - aid and attendence/housebound                                    0.986939
# hearing loss                                                               0.986892
# pension                                                                    0.986715
# service connected death                                                    0.980113
# unemployability                                                            0.973020
# eye (vision)                                                               0.954882
# respiratory                                                                0.954872
# musculoskeletal - ankle                                                    0.950974
# administrative issue                                                       0.950506
# musculoskeletal - knee                                                     0.949740
# musculoskeletal - shoulder                                                 0.949546
# special monthly compensation - aid and attendence/housebound               0.947917
# mental disorders                                                           0.939217
# musculoskeletal - hip                                                      0.936217
# heart/veins/arteries                                                       0.934385
# musculoskeletal - elbow                                                    0.933988
# endocrine                                                                  0.929790
# digestive                                                                  0.926391
# musculoskeletal - wrist                                                    0.925794
# post traumatic stress disorder (ptsd) combat - mental disorders            0.924795
# musculoskeletal - foot                                                     0.921415
# competency                                                                 0.919014
# birth defect in child                                                      0.916667
# cyst/benign growth - musculoskeletal - ankle                               0.914474
# musculoskeletal - neck/upper back (cervical spine)                         0.913481
# traumatic brain injury                                                     0.911463
# cancer - genitourinary                                                     0.908552
# cyst/benign growth - musculoskeletal - hip                                 0.905556
#                                                                              ...
# cyst/benign growth - gynecological                                         0.718137
# cyst/benign growth - musculoskeletal - neck/upper back (cervical spine)    0.716418
# neurological other system                                                  0.712371
# cancer - endocrine                                                         0.709199
# adhesions - gynecological                                                  0.700000
# musculoskeletal - osteomyelitis                                            0.696203
# leg condition - neurological other system                                  0.695910
# cancer - hemic and lymphatic                                               0.693856
# cyst/benign growth - neurological other system                             0.689441
# arm condition - neurological other system                                  0.672255
# cancer - heart/veins/arteries                                              0.666667
# musculoskeletal - other                                                    0.663262
# musculoskeletal - toe amputations                                          0.654545
# hemorrhage - neurological other system                                     0.648649
# musculoskeletal - amputations                                              0.647808
# musculoskeletal and muscle injuries                                        0.641307
# cyst/benign growth - genitourinary                                         0.635922
# cyst/benign growth - digestive                                             0.628866
# helpless child                                                             0.627803
# leg condition - heart/veins/arteries                                       0.610000
# cancer - musculoskeletal - other                                           0.574011
# hemorrhage - eye (vision)                                                  0.571429
# cyst/benign growth - respiratory                                           0.568627
# cyst/benign growth - skin                                                  0.567220
# adhesions - neurological other system                                      0.545455
# embolism/infarction - heart/veins/arteries                                 0.545455
# cyst/benign growth - musculoskeletal - other                               0.533762
# wound, bullet/shell fragment                                               0.500741
# arm condition - heart/veins/arteries                                       0.476190
# None                                                                       0.321950
# Name: correctPred, Length: 105, dtype: float64

# %%
results.groupby('validate')['correctPred'].mean().sort_values(ascending=False)[:32]
# Out:
# validate
# hearing loss                                                       0.994927
# pension                                                            0.987322
# service connected death                                            0.986515
# musculoskeletal - knee                                             0.973684
# pension - aid and attendence/housebound                            0.973477
# musculoskeletal - shoulder                                         0.971953
# musculoskeletal - ankle                                            0.971533
# eye (vision)                                                       0.965760
# respiratory                                                        0.965193
# musculoskeletal - hip                                              0.963634
# post traumatic stress disorder (ptsd) combat - mental disorders    0.961523
# heart/veins/arteries                                               0.960105
# mental disorders                                                   0.955517
# unemployability                                                    0.954893
# musculoskeletal - foot                                             0.954106
# musculoskeletal - mid/lower back (thoracolumbar spine)             0.953324
# musculoskeletal - elbow                                            0.950105
# traumatic brain injury                                             0.944573
# cancer - genitourinary                                             0.940346
# digestive                                                          0.939127
# musculoskeletal - wrist                                            0.935161
# administrative issue                                               0.932895
# musculoskeletal - hand                                             0.924876
# dental and oral                                                    0.918009
# musculoskeletal - neck/upper back (cervical spine)                 0.914592
# genitourinary                                                      0.908721
# endocrine                                                          0.906487
# special monthly compensation - aid and attendence/housebound       0.893999
# scars (extremeties and trunk)                                      0.892729
# skin                                                               0.889999
# competency                                                         0.887755
# neurological - cranial/peripheral nerves                           0.884698
# Name: correctPred, dtype: float64
